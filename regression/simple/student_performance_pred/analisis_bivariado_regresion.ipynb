# %% [markdown]
# Carga de librerías.

# %%
# librerías importantes

# %matplotlib inline
import numpy as np #for numerical
import pandas as pd #for datasets management
import seaborn as sns #for plots
import matplotlib.pyplot as plt #for show plots
from scipy import stats

# %% [markdown]
# Carga de datos.

# %%
db_original = 'exams.csv'
db = pd.read_csv(db_original)
db.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group D                some college      standard
# 1    male        group D          associate's degree      standard
# 2  female        group D                some college  free/reduced
# 3    male        group B                some college  free/reduced
# 4  female        group D          associate's degree      standard
#
#   test preparation course  math score  reading score  writing score
# 0               completed          59             70             78
# 1                    none          96             93             87
# 2                    none          57             76             77
# 3                    none          70             70             63
# 4                    none          83             85             86

# %% [markdown]
# Entendimiento de los datos.

# %%
print(db.dtypes) #tipos de datos en cada una de las columnas
print(db.shape) #cantidad de filas y columnas
# Out:
# CONSUMO    float64
# PRECIO     float64
# INGRESO      int64
# dtype: object
# (100, 3)

# %%
db.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')

# %%
print(db.corr()) #correlaciones entre TODAS las variables
#print(db.corr()['INGRESOS_OPERACIONALES_2017']) #correlaciones entre variable determinada y todas las variables
# Out:
#                math score  reading score  writing score
# math score       1.000000       0.811767       0.790055
# reading score    0.811767       1.000000       0.948909
# writing score    0.790055       0.948909       1.000000
# C:\Users\luisr\AppData\Local\Temp\ipykernel_16368\1671848727.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   print(db.corr()) #correlaciones entre TODAS las variables

# %%
sns.heatmap(db.corr())
plt.show()
# Out:
# C:\Users\luisr\AppData\Local\Temp\ipykernel_16368\361865887.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(db.corr())

# %%
lectura = db['reading score']
escritura = db['writing score']

#plotear histogramas de variables juntos
plt.figure(figsize= (15, 5))

#automovil
plt.subplot(1,2,1)
plt.hist(x = lectura, bins=15)
plt.title('Puntaje Matemáticas')

#moto
plt.subplot(1,2,2)
plt.hist(x = escritura, bins=15)
plt.title('Puntaje Lectura')
# Out:
# Text(0.5, 1.0, 'Puntaje Escritura')

# %% [markdown]
# Se predice X en base a Y

# %%
#join lectura/escritura
plt.figure(figsize = (10,10))
plt.subplot(2,2,2)
plt.scatter(x = lectura, y = escritura)
plt.title('Dispersión: Lectura / Escritura')

#distibución de lectura
plt.subplot(2,2,4)
plt.hist(x = lectura, bins = 15)
plt.title('Distribución de Lectura')

#distibución de escritura
plt.subplot(2,2,1)
plt.hist(x = escritura, orientation ='horizontal', bins = 15)
plt.title('Distribución de Escritura')
plt.show()

# %%
sns.regplot(x = reading, y = writing, fit_reg = False, scatter_kws = {"alpha": 0.5})
# Out:
# <Axes: xlabel='reading score', ylabel='writing score'>
